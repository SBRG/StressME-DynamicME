# %% [markdown]
# # Testing dynamicME on the latest cobrame model

# %%
CONSTRAIN_O2 = True
TUNE_GLPK = True     # GLPK for glycerol
TUNE_RESPIRATION = True

# %%
from dynamicme.dynamic import DynamicME
# Out:
# /usr/lib/python3.6/site-packages/cobra-0.5.11-py3.6-linux-x86_64.egg/cobra/solvers/__init__.py:63: UserWarning: No LP solvers found
#   warn("No LP solvers found")
# /usr/lib/python3.6/site-packages/cobra-0.5.11-py3.6-linux-x86_64.egg/cobra/io/sbml3.py:24: UserWarning: Install lxml for faster SBML I/O
#   warn("Install lxml for faster SBML I/O")
# /usr/lib/python3.6/site-packages/cobra-0.5.11-py3.6-linux-x86_64.egg/cobra/io/__init__.py:12: UserWarning: cobra.io.sbml requires libsbml
#   warn("cobra.io.sbml requires libsbml")

# %% [markdown]
# ## 1. Build the ME model anew
# ### Only need to run this once or if a new version of the ME model is released

# %%
# %run /source/ecolime/ecolime/build_me_model.py

# %% [markdown]
# ## 2. Load the built ME model

# %%
from cobrame.io.json import load_reduced_json_me_model, load_json_me_model
import pickle

# %%
with open('/source/ecolime/ecolime/me_models/iJL1678b.pickle','rb') as f:
    me = pickle.load(f)

# %%
rxn = me.reactions.get_by_id('GLYCtpp_REV_SPONT')
rxn.lower_bound = 0
rxn.upper_bound = 0

# %% [markdown]
# # 3. Set up the dynamic simulation

# %% [markdown]
# ## Here, we will simulate the complex medium originally investigated by [Beg et al., 2007](http://www.pnas.org/content/104/31/12663)

# %% [markdown]
# ### Metabolites to track

# %%
tracked_mets = [
    me.metabolites.ac_p,
    me.metabolites.gal_p,
    me.metabolites.glc__D_p,
    me.metabolites.glyc_p,
    me.metabolites.lac__L_p, 
    me.metabolites.malt_p
    ]
extra_rxns_tracked = [me.reactions.biomass_dilution, me.reactions.EX_o2_e]

# %% [markdown]
# ### Also track translation fluxes

# %%
rxns_trsl = me.reactions.query('translation_')
print(len(rxns_trsl))
extra_rxns_tracked = extra_rxns_tracked + rxns_trsl

from cobrame.core.reaction import MetabolicReaction
import pandas as pd

rows_tracked = []

for met_track in tracked_mets:
    mid_c = met_track.id.replace('_p','_c')
    mid_e = met_track.id.replace('_p','_e')
    met_c = me.metabolites.get_by_id(mid_c)
    met_e = me.metabolites.get_by_id(mid_e)
    for rxn in met_track.reactions:
        if isinstance(rxn, MetabolicReaction) and rxn.keff and met_c in rxn.metabolites or met_e in rxn.metabolites:
            extra_rxns_tracked.append(rxn)
            rows_tracked.append({'met':met_track.id, 'rxn':rxn.id})
            #print met_track,'\t', rxn.id, '\t', rxn.keff          
            
df_tracked = pd.DataFrame(rows_tracked)
# Out:
# 1569

# %%
dyme = DynamicME(me)

T = 10   # hours
V = 1.   # L
X0 = 0.00675 / V  # g/L
c0_dict = {'glc__D_e': 0.4,
           'lac__L_e': 0.4,
           'malt_e': 0.4,
           'gal_e': 0.4,
           'glyc_e':0.4,
           'ac_e': 0.0}
### Convert from g/L to mmol
for mid,c in c0_dict.items():
    met = me.metabolites.get_by_id(mid)
    c0_dict[met.id] = c / met.formula_weight * 1000

### Set max uptake rate
LB_EX = -10.
LB_O2 = -20.

lb_dict={}
ub_dict={}

for mid in c0_dict.keys():    
    rxn = dyme.get_exchange_rxn(mid)    
    if rxn.id == 'EX_o2_e':
        lb = LB_O2
    else:
        lb = LB_EX
    #rxn.lower_bound = lb
    lb_dict[rxn.id] = lb

#me.reactions.EX_o2_e.lower_bound = LB_O2
lb_dict[me.reactions.EX_o2_e.id] = LB_O2

print(c0_dict)
print(lb_dict)
print(ub_dict)

sim_params = {
    'T':T,
    'X0':X0,
    'c0_dict':c0_dict,
    'lb_dict':lb_dict,
    'ub_dict':ub_dict,
    'extra_rxns_tracked':extra_rxns_tracked,
    'ZERO_CONC':0.
}
# Out:
# {'glc__D_e': 2.220299442904667, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1685776026677226, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.0}
# {'EX_glc__D_e': -10.0, 'EX_lac__L_e': -10.0, 'EX_malt_e': -10.0, 'EX_gal_e': -10.0, 'EX_glyc_e': -10.0, 'EX_ac_e': -10.0, 'EX_o2_e': -20.0}
# {}

# %% [markdown]
# # 4. Some manual keff tuning from literature (see Methods)

# %%
growth_rxn = me.reactions.biomass_dilution
df_pert = df_tracked
groups = df_pert['met'].unique()

pert_rxns = [r for r in df_pert['rxn'].values]

group_rxn_dict = {met:df_pert[ df_pert['met']==met]['rxn'].values.tolist() for met in groups}
print(group_rxn_dict['malt_p'])
print(group_rxn_dict['glyc_p'])
# Out:
# ['MALTtexi_FWD_CPLX0-7655', 'MALTabcpp_FWD_ABC-16-CPLX']
# ['GLYCtex_REV_CPLX0-7534', 'GLYCtex_FWD_CPLX0-7534', 'GLYCtex_REV_CPLX0-7530', 'GLYCtex_FWD_CPLX0-7530', 'GLYCtex_REV_CPLX0-7533', 'GLYCtex_FWD_CPLX0-7533', 'GLYCtex_REV_G6700-MONOMER', 'GLYCtex_FWD_G6700-MONOMER', 'GLYCtpp_REV_SPONT', 'GLYCtpp_FWD_SPONT', 'GLYCtpp_REV_CPLX0-7654', 'GLYCtpp_FWD_CPLX0-7654']

# %%
rows_perturb_manual = []

# %% [markdown]
# ### Glycerol
#
# ### Glycerol kinase (GLPK) known to be rate-limiting (Applebee et al., 2011)

# %%
### From Applebee et al. (2011)
vmax_glpk_ale = 86
vmax_glpk_wt  = 18.1

for rxn in me.process_data.GLYK.parent_reactions:
    extra_rxns_tracked.append(rxn)
    rows_perturb_manual.append({'met':'glyc_p', 'rxn':rxn.id})
    if TUNE_GLPK:
        keff1 = rxn.keff
        keff2 = keff1 * vmax_glpk_wt / vmax_glpk_ale
        print('Changing keff for %s from %g to %g'%(rxn.id, keff1, keff2))
        rxn.keff = keff2
        rxn.update()
        print(rxn.id, ':\t', rxn.reaction    )
# Out:
# Changing keff for GLYK_FWD_GLYCEROL-KIN-CPLX_mod_mg2 from 122.117 to 25.7013
# GLYK_FWD_GLYCEROL-KIN-CPLX_mod_mg2 :	 1.08079063567606e-5*mu GLYCEROL-KIN-CPLX_mod_mg2 + atp_c + glyc_c --> adp_c + glyc3p_c + h_c
# Changing keff for GLYK_FWD_GLYCEROL-KIN-CPLX_mod_mn2 from 122.117 to 25.7013
# GLYK_FWD_GLYCEROL-KIN-CPLX_mod_mn2 :	 1.08079063567606e-5*mu GLYCEROL-KIN-CPLX_mod_mn2 + atp_c + glyc_c --> adp_c + glyc3p_c + h_c

# %% [markdown]
# ### Respiration
# Basan et al. (2015) Nat: proteome cost of energy biogenesis by respiration exceeds that by fermentation
# - TCA
# - Cytochromes
# - ATP synthase

# %%
### Isocitrate dehyrogenase keffs were way too high
for rxn in me.process_data.ICDHyr.parent_reactions:
    extra_rxns_tracked.append(rxn)
    rows_perturb_manual.append({'met':'o2_e', 'rxn':rxn.id})
    if TUNE_RESPIRATION:
        keff1 = rxn.keff
        keff2 = 11900./60   # BIONUMBERS http://bionumbers.hms.harvard.edu/bionumber.aspx?id=101152
        # 106.4    ### BRENDA for 40oC
        if keff2 < keff1:
            print('Changing keff for %s from %g to %g'%(rxn.id, keff1, keff2))
            rxn.keff = keff2
            rxn.update()
            print(rxn.id, ':\t', rxn.reaction)

### ATP Synthase: 
# F0F1: 270 +/- 40 s-1: http://www.ncbi.nlm.nih.gov/pubmed/9030757

### Cytochromes
# Zhuang (2011)
# Cyd-II: low cost
# Cyo: costly
# Cyd-I: preferred in microaerobic
# Cytochrome oxidase bo3 (ubiquinol-8: 4 protons)
for rxn in me.process_data.CYTBO3_4pp.parent_reactions:
    extra_rxns_tracked.append(rxn)
    rows_perturb_manual.append({'met':'o2_e', 'rxn':rxn.id})
    if TUNE_RESPIRATION:
        keff1 = rxn.keff
        keff2 = 300. # http://www.brenda-enzymes.org/enzyme.php?ecno=1.9.3.1
        if keff2 < keff1:
            print('Changing keff for %s from %g to %g'%(rxn.id, keff1, keff2))
            rxn.keff = keff2
            rxn.update()
            print(rxn.id, ':\t', rxn.reaction)
            
# Cytochrome oxidase bd (menaquinol-8: 2 protons)
for rxn in me.process_data.CYTBD2pp.parent_reactions:
    extra_rxns_tracked.append(rxn)
    rows_perturb_manual.append({'met':'o2_e', 'rxn':rxn.id})
    if TUNE_RESPIRATION:
        keff1 = rxn.keff
        keff2 = keff1 / 2.
        if keff2 < keff1:
            print('Changing keff for %s from %g to %g'%(rxn.id, keff1, keff2))
            rxn.keff = keff2
            rxn.update()
            print(rxn.id, ':\t', rxn.reaction)
            
# Cytochrome oxidase bd (ubiquinol-8: 2 protons)
for rxn in me.process_data.CYTBDpp.parent_reactions:
    extra_rxns_tracked.append(rxn)
    rows_perturb_manual.append({'met':'o2_e', 'rxn':rxn.id})
    if TUNE_RESPIRATION:
        keff1 = rxn.keff
        keff2 = keff1 / 2.
        if keff2 < keff1:
            print('Changing keff for %s from %g to %g'%(rxn.id, keff1, keff2))
            rxn.keff = keff2
            rxn.update()
            print(rxn.id, ':\t', rxn.reaction)
# Out:
# Changing keff for ICDHyr_FWD_ISOCITHASE-CPLX_mod_mn2 from 3000 to 198.333
# ICDHyr_FWD_ISOCITHASE-CPLX_mod_mn2 :	 1.40056022408964e-6*mu ISOCITHASE-CPLX_mod_mn2 + icit_c + nadp_c --> akg_c + co2_c + nadph_c
# Changing keff for ICDHyr_FWD_ISOCITHASE-CPLX_mod_mg2 from 3000 to 198.333
# ICDHyr_FWD_ISOCITHASE-CPLX_mod_mg2 :	 1.40056022408964e-6*mu ISOCITHASE-CPLX_mod_mg2 + icit_c + nadp_c --> akg_c + co2_c + nadph_c
# Changing keff for CYTBO3_4pp_FWD_CYT-O-UBIOX-CPLX_mod_pheme_mod_hemeO_mod_cu2 from 3000 to 300
# CYTBO3_4pp_FWD_CYT-O-UBIOX-CPLX_mod_pheme_mod_hemeO_mod_cu2 :	 9.25925925925926e-7*mu CYT-O-UBIOX-CPLX_mod_pheme_mod_hemeO_mod_cu2 + 4.0 h_c + 0.5 o2_c + q8h2_c --> h2o_c + 4.0 h_p + q8_c
# Changing keff for CYTBD2pp_FWD_APP-UBIOX-CPLX_mod_pheme_mod_hemed from 66.6717 to 33.3358
# CYTBD2pp_FWD_APP-UBIOX-CPLX_mod_pheme_mod_hemed :	 8.33270537899445e-6*mu APP-UBIOX-CPLX_mod_pheme_mod_hemed + 2.0 h_c + mql8_c + 0.5 o2_c --> h2o_c + 2.0 h_p + mqn8_c
# Changing keff for CYTBDpp_FWD_APP-UBIOX-CPLX_mod_pheme_mod_hemed from 66.6717 to 33.3358
# CYTBDpp_FWD_APP-UBIOX-CPLX_mod_pheme_mod_hemed :	 8.33270537899445e-6*mu APP-UBIOX-CPLX_mod_pheme_mod_hemed + 2.0 h_c + 0.5 o2_c + q8h2_c --> h2o_c + 2.0 h_p + q8_c
# Changing keff for CYTBDpp_FWD_CYT-D-UBIOX-CPLX_mod_pheme_mod_hemed from 66.8259 to 33.4129
# CYTBDpp_FWD_CYT-D-UBIOX-CPLX_mod_pheme_mod_hemed :	 8.31347910917491e-6*mu CYT-D-UBIOX-CPLX_mod_pheme_mod_hemed + 2.0 h_c + 0.5 o2_c + q8h2_c --> h2o_c + 2.0 h_p + q8_c

# %%
df_pert_manual = pd.DataFrame(rows_perturb_manual).drop_duplicates()
print(df_pert_manual.shape)
# Out:
# (10, 2)

# %%
# Append timestamp to filename
import time
timestr = '_'+time.strftime("%Y%m%d_%H%M")
print(timestr)

# Append simulation conditions to filename
simstr = ''
if TUNE_GLPK: simstr = simstr + '_GLPK'
if TUNE_RESPIRATION: simstr = simstr + '_RESP'

print(simstr)
# Out:
# _20250729_0003
# _GLPK_RESP

# %% [markdown]
# # 5. Perform DynamicME simulation

# %%
dyme = DynamicME(me)

# %%
import time

tic = time.time()

if CONSTRAIN_O2:
    result = dyme.simulate_batch(T, c0_dict, X0, prec_bs=1e-3, ZERO_CONC=0., extra_rxns_tracked=extra_rxns_tracked,
                             lb_dict={'EX_o2_e': -18.5}, verbosity=1)
else:
    result = dyme.simulate_batch(T, c0_dict, X0, prec_bs=1e-3, ZERO_CONC=0., extra_rxns_tracked=extra_rxns_tracked,
                             lb_dict={}, verbosity=0)
    
toc = time.time()-tic
# Out:
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e depleted.
# Computing new uptake rates
# Finished compiling expressions in 57.783828 seconds
# Finished substituting S,lb,ub in 3.906314 seconds
# Finished makeME_LP in 0.707877 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.895098 seconds
# Finished makeME_LP in 0.689389 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.873327 seconds
# Finished makeME_LP in 0.689182 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.882596 seconds
# Finished makeME_LP in 0.690402 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.879497 seconds
# Finished makeME_LP in 0.692231 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.851269 seconds
# Finished makeME_LP in 0.683695 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.862298 seconds
# Finished makeME_LP in 0.687857 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.874886 seconds
# Finished makeME_LP in 0.683208 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.857765 seconds
# Finished makeME_LP in 0.691485 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.832398 seconds
# Finished makeME_LP in 0.687881 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.857138 seconds
# Finished makeME_LP in 0.685998 seconds
# Getting MINOS parameters from ME_NLP...
# Biomass at t=0.1: 0.00730437
# Concentrations: {'glc__D_e': 2.2137144989417994, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1684925055461064, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.00034393687000889867}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Computing new uptake rates
# Finished substituting S,lb,ub in 3.878115 seconds
# Finished makeME_LP in 0.692307 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.866566 seconds
# Finished makeME_LP in 0.690105 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.860330 seconds
# Finished makeME_LP in 0.682316 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.857334 seconds
# Finished makeME_LP in 0.684278 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.857084 seconds
# Finished makeME_LP in 0.684740 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.838589 seconds
# Finished makeME_LP in 0.684700 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.888148 seconds
# Finished makeME_LP in 0.693463 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.994678 seconds
# Finished makeME_LP in 0.708522 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.007888 seconds
# Finished makeME_LP in 0.751530 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.023788 seconds
# Finished makeME_LP in 0.729753 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.028678 seconds
# Finished makeME_LP in 0.714842 seconds
# Getting MINOS parameters from ME_NLP...
# Biomass at t=0.2: 0.00790427
# Concentrations: {'glc__D_e': 2.2065887407335443, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.168400419490967, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.0007161208989706766}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=0.3: 0.00855344
# Concentrations: {'glc__D_e': 2.198877751797443, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.168300770508838, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.0011188719951548036}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=0.4: 0.00925592
# Concentrations: {'glc__D_e': 2.1905334677739137, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.168192937464798, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.0015547005983595217}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=0.5: 0.0100161
# Concentrations: {'glc__D_e': 2.1815038768300927, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1680762482107931, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.0020263233280579085}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=0.6: 0.0108387
# Concentrations: {'glc__D_e': 2.171732695458171, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1679499753959859, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.0025366799167090633}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=0.7: 0.0117289
# Concentrations: {'glc__D_e': 2.1611590176474027, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1678133319330095, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.0030889515337836184}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=0.8: 0.0126922
# Concentrations: {'glc__D_e': 2.149716935242996, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1676654660918726, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.0036865806147214257}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=0.9: 0.0137346
# Concentrations: {'glc__D_e': 2.1373351271254935, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1675054561909313, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.004333292318419848}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=1: 0.0148626
# Concentrations: {'glc__D_e': 2.123936414649903, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1673323048518365, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.005033117747002095}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=1.1: 0.0160832
# Concentrations: {'glc__D_e': 2.109437280573534, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1671449327826462, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.00579041907259974}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=1.2: 0.0174041
# Concentrations: {'glc__D_e': 2.093747348473901, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1669421720503514, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.006609916727770395}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=1.3: 0.0188335
# Concentrations: {'glc__D_e': 2.0767688194117877, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1667227588008828, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.007496718829034655}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=1.4: 0.0203803
# Concentrations: {'glc__D_e': 2.0583958623280694, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1664853253812186, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.00845635301693595}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=1.5: 0.0220541
# Concentrations: {'glc__D_e': 2.0385139543744875, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1662283918144902, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.009494800911089687}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=1.6: 0.0238653
# Concentrations: {'glc__D_e': 2.0169991670665146, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1659503565749476, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.010618535394987886}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=1.7: 0.0258254
# Concentrations: {'glc__D_e': 1.9937173938087365, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1656494866052824, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.011834560962964051}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=1.8: 0.0279464
# Concentrations: {'glc__D_e': 1.9685235139777364, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.165323906514085, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.013150457380810134}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=1.9: 0.0302416
# Concentrations: {'glc__D_e': 1.9412604883520224, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1649715868861008, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.014574426932192209}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=2: 0.0327253
# Concentrations: {'glc__D_e': 1.9117583802506029, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.16459033163242, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.016115345545362595}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=2.1: 0.035413
# Concentrations: {'glc__D_e': 1.8798332962787445, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1641777643017521, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.017782818118852933}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=2.2: 0.0383214
# Concentrations: {'glc__D_e': 1.8452862400783379, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.163731313267462, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.019587238391005905}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=2.3: 0.0414687
# Concentrations: {'glc__D_e': 1.8079018719380346, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1632481956980316, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.02153985372652613}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=2.4: 0.0448745
# Concentrations: {'glc__D_e': 1.767447166531521, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1627254002110337, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.023652835223879606}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=2.5: 0.04856
# Concentrations: {'glc__D_e': 1.7236699604173045, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1621596681024962, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.02593935358053721}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=2.6: 0.0525482
# Concentrations: {'glc__D_e': 1.6762973802462464, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.161547473034654, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.028413661188947652}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=2.7: 0.0568639
# Concentrations: {'glc__D_e': 1.625034141879499, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1608849990554784, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.031091180974962898}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=2.8: 0.0615341
# Concentrations: {'glc__D_e': 1.5695607098148574, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1601681168129738, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.03398860253246631}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=2.9: 0.0665878
# Concentrations: {'glc__D_e': 1.5095313054488133, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1593923578159824, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.03712398615343264}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=3: 0.0720566
# Concentrations: {'glc__D_e': 1.444571751759347, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1585528865810546, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.040516875401863106}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=3.1: 0.0779745
# Concentrations: {'glc__D_e': 1.3742771409748766, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1576444704917737, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.04418841893329455}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=3.2: 0.0843785
# Concentrations: {'glc__D_e': 1.2982093106914083, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1566614471826602, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.04816150231921172}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=3.3: 0.0913084
# Concentrations: {'glc__D_e': 1.2158941127059482, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1555976892443511, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.05246089069805432}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=3.4: 0.0988075
# Concentrations: {'glc__D_e': 1.1268184575421898, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.154446566030054, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.05711338314199522}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=3.5: 0.106922
# Concentrations: {'glc__D_e': 1.0304271162463299, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1532009023252077, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.062147979701693376}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=3.6: 0.115704
# Concentrations: {'glc__D_e': 0.9261192595178704, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1518529336227268, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.06759606217024955}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=3.7: 0.125206
# Concentrations: {'glc__D_e': 0.813244712603021, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.150394257725052, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.07349158969310804}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=3.8: 0.13549
# Concentrations: {'glc__D_e': 0.6910999026065906, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.148815782371328, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.07987131044318567}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=3.9: 0.146617
# Concentrations: {'glc__D_e': 0.5589234729610393, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1471076685632602, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.08677499068064762}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Biomass at t=4: 0.158659
# Concentrations: {'glc__D_e': 0.4158915377166688, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.145259269236385, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.09424566262511205}
# Metabolite glc__D_e available.
# Using default LB=-1000 for EX_glc__D_e
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Changing lower bounds glc__D_e to -16.458
# Biomass at t=4.1: 0.171689
# Concentrations: {'glc__D_e': 0.2611125460718574, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1432590628944803, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.10232989268532791}
# Metabolite glc__D_e available.
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Computing new uptake rates
# Finished substituting S,lb,ub in 4.266857 seconds
# Finished makeME_LP in 0.789610 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.066285 seconds
# Finished makeME_LP in 0.700621 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.955766 seconds
# Finished makeME_LP in 0.691777 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.909181 seconds
# Finished makeME_LP in 0.695534 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.053121 seconds
# Finished makeME_LP in 0.696040 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.968181 seconds
# Finished makeME_LP in 0.694126 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.832898 seconds
# Finished makeME_LP in 0.685317 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.838982 seconds
# Finished makeME_LP in 0.685375 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.836114 seconds
# Finished makeME_LP in 0.685553 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.868734 seconds
# Finished makeME_LP in 0.693120 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.116376 seconds
# Finished makeME_LP in 0.704942 seconds
# Getting MINOS parameters from ME_NLP...
# Changing lower bounds glc__D_e to -5.453
# Biomass at t=4.2: 0.18579
# Concentrations: {'glc__D_e': 0.09362172513277972, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.1410945817934408, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.11107807171826267}
# Metabolite glc__D_e available.
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Computing new uptake rates
# Finished substituting S,lb,ub in 3.927054 seconds
# Finished makeME_LP in 0.692018 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.054189 seconds
# Finished makeME_LP in 0.694754 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.987394 seconds
# Finished makeME_LP in 0.705816 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.059378 seconds
# Finished makeME_LP in 0.714251 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.963209 seconds
# Finished makeME_LP in 0.705749 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.953391 seconds
# Finished makeME_LP in 0.705771 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.963923 seconds
# Finished makeME_LP in 0.700489 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.128854 seconds
# Finished makeME_LP in 0.701325 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.975045 seconds
# Finished makeME_LP in 0.719500 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.988758 seconds
# Finished makeME_LP in 0.698648 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.034748 seconds
# Finished makeME_LP in 0.718232 seconds
# Getting MINOS parameters from ME_NLP...
# glc__D_e below threshold, reset run flag triggered
# Changing lower bounds glc__D_e to -4.658
# Resetting run
# Metabolite glc__D_e available.
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Computing new uptake rates
# Finished substituting S,lb,ub in 3.998007 seconds
# Finished makeME_LP in 0.690713 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.953598 seconds
# Finished makeME_LP in 0.717018 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.143327 seconds
# Finished makeME_LP in 0.791996 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.050838 seconds
# Finished makeME_LP in 0.693895 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.045970 seconds
# Finished makeME_LP in 0.698127 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.985629 seconds
# Finished makeME_LP in 0.691500 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.153577 seconds
# Finished makeME_LP in 0.692471 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.048922 seconds
# Finished makeME_LP in 0.712018 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.115165 seconds
# Finished makeME_LP in 0.701622 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.237278 seconds
# Finished makeME_LP in 0.722782 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.145859 seconds
# Finished makeME_LP in 0.721937 seconds
# Getting MINOS parameters from ME_NLP...
# Changing lower bounds glc__D_e to -0.000
# Biomass at t=4.3: 0.200994
# Concentrations: {'glc__D_e': 8.45037685104355e-06, 'lac__L_e': 4.4908498933423155, 'malt_e': 1.0951818694657682, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.12052024126412568}
# Metabolite glc__D_e available.
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Computing new uptake rates
# Finished substituting S,lb,ub in 4.017005 seconds
# Finished makeME_LP in 0.707770 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.031267 seconds
# Finished makeME_LP in 0.688496 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.829729 seconds
# Finished makeME_LP in 0.686026 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.832065 seconds
# Finished makeME_LP in 0.684290 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.837222 seconds
# Finished makeME_LP in 0.683634 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.845243 seconds
# Finished makeME_LP in 0.685915 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.878476 seconds
# Finished makeME_LP in 0.688077 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.867796 seconds
# Finished makeME_LP in 0.697305 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.860085 seconds
# Finished makeME_LP in 0.685474 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.872961 seconds
# Finished makeME_LP in 0.691557 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 4.038673 seconds
# Finished makeME_LP in 0.681822 seconds
# Getting MINOS parameters from ME_NLP...
# Changing lower bounds glc__D_e to 0.000
# Biomass at t=4.4: 0.217344
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': 4.4908498933423155, 'malt_e': 0.9955067286490369, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.1306864580168076}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Computing new uptake rates
# Finished substituting S,lb,ub in 3.844052 seconds
# Finished makeME_LP in 0.686852 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.861018 seconds
# Finished makeME_LP in 0.701853 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.836868 seconds
# Finished makeME_LP in 0.684711 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.844643 seconds
# Finished makeME_LP in 0.692518 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.857127 seconds
# Finished makeME_LP in 0.685770 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.826413 seconds
# Finished makeME_LP in 0.691071 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.863730 seconds
# Finished makeME_LP in 0.683717 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.818852 seconds
# Finished makeME_LP in 0.690849 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.866417 seconds
# Finished makeME_LP in 0.687974 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.826841 seconds
# Finished makeME_LP in 0.689026 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.853790 seconds
# Finished makeME_LP in 0.686229 seconds
# Getting MINOS parameters from ME_NLP...
# Changing lower bounds glc__D_e to 0.000
# Biomass at t=4.5: 0.235025
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': 4.4908498933423155, 'malt_e': 0.8877179034713125, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.14167967372481363}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Changing lower bounds glc__D_e to 0.000
# Biomass at t=4.6: 0.254144
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': 4.4908498933423155, 'malt_e': 0.7711607099954394, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.15356716176531665}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Changing lower bounds glc__D_e to 0.000
# Biomass at t=4.7: 0.274818
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': 4.4908498933423155, 'malt_e': 0.6451218620112261, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.1664216690966145}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Changing lower bounds glc__D_e to 0.000
# Biomass at t=4.8: 0.297173
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': 4.4908498933423155, 'malt_e': 0.5088300491470471, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.18032186047156185}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Changing lower bounds glc__D_e to 0.000
# Biomass at t=4.9: 0.321348
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': 4.4908498933423155, 'malt_e': 0.36145121674030345, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.19535279983628764}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Using default LB=-1000 for EX_malt_e
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds malt_e to -6.289
# Biomass at t=5: 0.347489
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': 4.4908498933423155, 'malt_e': 0.20208346173640968, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.21160647088956974}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Computing new uptake rates
# Finished substituting S,lb,ub in 3.870621 seconds
# Finished makeME_LP in 0.690624 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.825015 seconds
# Finished makeME_LP in 0.689552 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.839921 seconds
# Finished makeME_LP in 0.686423 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.834962 seconds
# Finished makeME_LP in 0.680556 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.838810 seconds
# Finished makeME_LP in 0.686451 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.847552 seconds
# Finished makeME_LP in 0.684496 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.842085 seconds
# Finished makeME_LP in 0.681824 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.812770 seconds
# Finished makeME_LP in 0.683329 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.819613 seconds
# Finished makeME_LP in 0.686570 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.837777 seconds
# Finished makeME_LP in 0.682926 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.829615 seconds
# Finished makeME_LP in 0.683750 seconds
# Getting MINOS parameters from ME_NLP...
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds malt_e to -0.856
# Biomass at t=5.1: 0.375756
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': 4.4908498933423155, 'malt_e': 0.029751513381124944, 'gal_e': 2.220299442904667, 'glyc_e': 4.34339676647141, 'ac_e': 0.22918233998849483}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Computing new uptake rates
# Finished substituting S,lb,ub in 3.844229 seconds
# Finished makeME_LP in 0.685339 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.822554 seconds
# Finished makeME_LP in 0.683751 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.836159 seconds
# Finished makeME_LP in 0.685118 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.833219 seconds
# Finished makeME_LP in 0.683784 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.846295 seconds
# Finished makeME_LP in 0.682176 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.851783 seconds
# Finished makeME_LP in 0.682093 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.860740 seconds
# Finished makeME_LP in 0.684822 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.850552 seconds
# Finished makeME_LP in 0.690104 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.852061 seconds
# Finished makeME_LP in 0.684978 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.850387 seconds
# Finished makeME_LP in 0.681322 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.834302 seconds
# Finished makeME_LP in 0.682170 seconds
# Getting MINOS parameters from ME_NLP...
# Changing lower bounds glc__D_e to 0.000
# malt_e below threshold, reset run flag triggered
# Changing lower bounds malt_e to -0.733
# Resetting run
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# Metabolite malt_e available.
# Metabolite gal_e available.
# Using default LB=-1000 for EX_gal_e
# Metabolite glyc_e available.
# Using default LB=-1000 for EX_glyc_e
# Metabolite ac_e available.
# Using default LB=-1000 for EX_ac_e
# Computing new uptake rates
# Finished substituting S,lb,ub in 3.866673 seconds
# Finished makeME_LP in 0.687905 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.873457 seconds
# Finished makeME_LP in 0.686423 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.848033 seconds
# Finished makeME_LP in 0.683440 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.833152 seconds
# Finished makeME_LP in 0.681156 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.822957 seconds
# Finished makeME_LP in 0.684463 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.843067 seconds
# Finished makeME_LP in 0.691361 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.854342 seconds
# Finished makeME_LP in 0.684962 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.841369 seconds
# Finished makeME_LP in 0.686684 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.849737 seconds
# Finished makeME_LP in 0.683181 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.816765 seconds
# Finished makeME_LP in 0.687299 seconds
# Getting MINOS parameters from ME_NLP...
# Finished substituting S,lb,ub in 3.836393 seconds
# Finished makeME_LP in 0.686398 seconds
# Getting MINOS parameters from ME_NLP...
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds malt_e to -0.000
# Biomass at t=5.2: 0.405919
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': 4.166670904728981, 'malt_e': 2.6892807901239546e-06, 'gal_e': 2.0502841405499073, 'glyc_e': 4.34339676647141, 'ac_e': 0.2479344444702852}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e available.
# Using default LB=-1000 for EX_lac__L_e
# ...
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=7.4: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=7.5: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=7.6: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=7.7: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=7.8: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=7.9: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=8: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=8.1: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=8.2: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=8.3: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=8.4: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=8.5: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=8.6: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=8.7: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=8.8: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=8.9: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=9: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=9.1: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=9.2: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=9.3: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=9.4: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=9.5: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=9.6: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=9.7: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=9.8: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=9.9: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=10: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}
# Metabolite glc__D_e depleted.
# Metabolite lac__L_e depleted.
# Metabolite malt_e depleted.
# Metabolite gal_e depleted.
# Metabolite glyc_e available.
# Metabolite ac_e available.
# Changing lower bounds glc__D_e to 0.000
# Changing lower bounds lac__L_e to 0.000
# Changing lower bounds malt_e to 0.000
# Changing lower bounds gal_e to 0.000
# Biomass at t=10.1: 0.939914
# Concentrations: {'glc__D_e': -1.4352183883252958e-06, 'lac__L_e': -1.374949444413366e-05, 'malt_e': -4.482337603309835e-07, 'gal_e': -6.964913736413908e-06, 'glyc_e': 0.0006502077206722578, 'ac_e': 0.00025335044333296003}

# %%
print('%g seconds'%toc)
# Out:
# 2124.91 seconds

# %% [markdown]
# # 6. Convert solution's metabolite concentrations from mM to g/L

# %%
from dynamicme.dynamic import ParamOpt

popt = ParamOpt(me, sim_params, growth_rxn=growth_rxn.id)
sol = popt.compute_conc_profile(result)

# %%
df_mw = pd.DataFrame([{'id':m.id,'mass':m.mass if hasattr(m,'mass') else m.formula_weight,'name':m.name} for m in me.metabolites])

sol_gL = sol.copy()
variables = c0_dict.keys()

for col in sol.columns:
    if col in variables:
        c_mM = sol[col]
        mw = df_mw[ df_mw.id==col].mass.values[0]
        c_gL = c_mM * mw / 1000.
        sol_gL[col] = c_gL
        
df_ex = pd.DataFrame(result['ex_flux'])

# %% [markdown]
# # 7. Plot metabolite concentration profiles

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

dsplot = sol_gL[[c for c in sol_gL.columns if c != 'biomass' and 'EX_' not in c]].melt(id_vars='time')

dsplot.variable.unique()

palette = ['#660066','#00FF00','#000000','#FF00FF','#0000FF','#FF0000']
sns.set_palette(palette)
g = sns.FacetGrid(dsplot, hue='variable', size=5)
g.map(plt.plot, 'time','value')
g.add_legend()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-44e3d54388b0> in <module>()
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4
#       5 dsplot = sol_gL[[c for c in sol_gL.columns if c != 'biomass' and 'EX_' not in c]].melt(id_vars='time')
#
# ModuleNotFoundError: No module named 'seaborn'
